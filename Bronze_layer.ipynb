# %%
print("Hello Developer")

# %%
# %sql
select "TJ"

# %%
# %sql
create volume databricks_lamba.bronze.bronzeVol

# %%
# %sql
select * from csv.`/Volumes/databricks_lamba/bronze/bronzevol/Sales/fact_sales.csv`

# %% [markdown]
# ##### **DBUTILS**

# %%
dbutils.help()

# %%
dbutils.help('fs')

# %%
#dbutils.fs.ls('/Volumes/databricks_lamba/bronze/bronzevol/customer')

# all_files = dbutils.fs.ls('/Volumes/databricks_lamba/bronze/bronzevol/customer/')
# all_files

file_names = [i.name for i in all_files]
file_names

# %%
dbutils.fs.mkdirs('/Volumes/databricks_lamba/bronze/bronzevol/customer')

# %%
dbutils.fs.cp('/Volumes/databricks_lamba/bronze/bronzevol/Sales','/Volumes/databricks_lamba/bronze/bronzevol/customer',True)

# %%
dbutils.fs.rm('/Volumes/databricks_lamba/bronze/bronzevol/customer/fact_sales.csv')

# %%
dbutils.fs.put('/Volumes/databricks_lamba/bronze/bronzevol/customer/test.txt','This is a test',True)

# %%
dbutils.widgets.text('para1',"")

# %%
dbutils.widgets.get('para1') #useful to create ETL pipelines

# %%
for i in file_names:
    dbutils.fs.rm(f'/Volumes/databricks_lamba/bronze/bronzevol/customer/{i}')
