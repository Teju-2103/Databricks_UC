# %%
with open("/Workspace/Users/tejashriadawade21@gmail.com/Databricks_UC/Test.txt","r") as f:
  content = f.read()
  print(content)

# %%
with open("/Workspace/Users/tejashriadawade21@gmail.com/Databricks_UC/Test2.txt","w") as f:
    f.write("hello pyspark devloper")

# %%
with open("/Workspace/Users/tejashriadawade21@gmail.com/Databricks_UC/Test3.py","w") as f:
    f.write("my_secret='1234'")

# %%
import Test3

# %%
Test3.my_secret

# %% [markdown]
# #### **JSON FILES (MAPPING FILES)**

# %%
import pandas as pd
df= pd.read_json("/Workspace/Users/tejashriadawade21@gmail.com/Databricks_UC/mapping.json")
df.head()

# %%
# convert it into pyspark dataframe

df_pysaprk = spark.createDataFrame(df)
df_pysaprk.display()
